# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.4/778.4 kB 26.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -U ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 63.4 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
from ultralytics import YOLO
import os

# %%
model = YOLO('yolov8s.pt')
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 265MB/s]

# %%
results = model.train(
    data= '/kaggle/input/80-10-10-dataset/data.yaml',
    epochs=100,
    imgsz=640,
    patience=50,
    device=0,
    batch=64,
    optimizer= 'SGD',
    momentum=0.95
)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#model = YOLO("/kaggle/input/best-model/best_80_10_10.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /kaggle/input/80-10-10-dataset/valid/labels... 1016 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1016/1016 [00:01<00:00, 796.48it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/80-10-10-dataset/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:17<00:00,  1.12s/it]
#                    all       1016       1872      0.922       0.87      0.938      0.635
#               Drowning       1016       1107      0.919      0.876      0.945      0.655
#               Swimming       1016        707      0.882      0.871      0.909      0.578
#           out of water       1016         58      0.964      0.862      0.959      0.673
# ...

# %% [markdown]
# Testing

# %%
#model = YOLO("/kaggle/input/best-model/best_80_10_10.pt")  

video_path = "/kaggle/input/testing-video/drowning_video_testing.mp4"  # Replace with the path to your video file

results = model.predict(video_path)

# %% [markdown]
# tunning

# %%
model = YOLO("/kaggle/input/best-model/best_80_10_10.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = YOLO("/kaggle/input/best-model/best_80_10_10.pt")
#
# NameError: name 'YOLO' is not defined

# %%
results = model.train(
    data='/kaggle/input/80-10-10-dataset/data.yaml',
    epochs=50,
    imgsz=640,
    patience=30,  
    device=0,
    batch=32,  
    optimizer='SGD',  
    lr0=0.001,  
    lrf=0.005,
    momentum=0.9,
    warmup_momentum=0.5,
    warmup_bias_lr=0.05,
    weight_decay=0.0005,  
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 results = model.train(
#       2     data='/kaggle/input/80-10-10-dataset/data.yaml',
#       3     epochs=50,
#       4     imgsz=640,
#       5     patience=30,
#       6     device=0,
#       7     batch=32,
#       8     optimizer='SGD',
#       9     lr0=0.001,
#      10     lrf=0.005,
#      11     momentum=0.9,
#      12     warmup_momentum=0.5,
#      13     warmup_bias_lr=0.05,
#      14     weight_decay=0.0005,
#      15 )
#
# NameError: name 'model' is not defined
